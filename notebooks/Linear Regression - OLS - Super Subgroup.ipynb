# %% [markdown]
# # Stats Models

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import plotly.graph_objects as go

# %%
unweighted = pd.read_pickle('../data/school_based/assessments_clean.pkl')

# %%
unweighted
# Out:
#         year                  system_name                 school_name  \
# 0       2018  Achievement School District              Aspire Coleman
# 1       2018  Achievement School District              Aspire Coleman
# 2       2018  Achievement School District              Aspire Coleman
# 3       2018  Achievement School District              Aspire Coleman
# 4       2018  Achievement School District              Aspire Coleman
# ...      ...                          ...                         ...
# 381475  2022                Wilson County  Wilson Central High School
# 381476  2022                Wilson County  Wilson Central High School
# 381477  2022                Wilson County  Wilson Central High School
# 381479  2022                Wilson County  Wilson Central High School
# 381480  2022                Wilson County  Wilson Central High School
#
#            test   subject subject_area  \
# 0       TNReady       ELA          ELA
# 1       TNReady       ELA          ELA
# 2       TNReady       ELA          ELA
# 3       TNReady       ELA          ELA
# 4       TNReady       ELA          ELA
# ...         ...       ...          ...
# 381475      EOC  Geometry         Math
# 381476      EOC  Geometry         Math
# 381477      EOC  Geometry         Math
# 381479      EOC  Geometry         Math
# 381480      EOC  Geometry         Math
#
#                                  student_group  valid_tests  pct_met_exceeded  \
# 0                                 All Students        321.0             0.112
# 1                    Black or African American        299.0             0.114
# 2               Black/Hispanic/Native American        312.0             0.115
# 3                   Economically Disadvantaged        222.0             0.095
# 4       English Learners with Transitional 1-4         11.0             0.182
# ...                                        ...          ...               ...
# 381475          Non-Economically Disadvantaged        324.0             0.432
# 381476   Non-English Learners/Transitional 1-4        331.0             0.432
# 381477          Non-Students with Disabilities        335.0             0.445
# 381479                          Super Subgroup        129.0             0.202
# 381480                                   White        280.0             0.471
#
#           system  ... charter      virtual title_1       lat       long  \
# 0       TN-00985  ...       1   NOTVIRTUAL       1  35.21410 -89.923641
# 1       TN-00985  ...       1   NOTVIRTUAL       1  35.21410 -89.923641
# 2       TN-00985  ...       1   NOTVIRTUAL       1  35.21410 -89.923641
# 3       TN-00985  ...       1   NOTVIRTUAL       1  35.21410 -89.923641
# 4       TN-00985  ...       1   NOTVIRTUAL       1  35.21410 -89.923641
# ...          ...  ...     ...          ...     ...       ...        ...
# 381475  TN-00950  ...       0  SUPPVIRTUAL       0  36.13409 -86.395110
# 381476  TN-00950  ...       0  SUPPVIRTUAL       0  36.13409 -86.395110
# 381477  TN-00950  ...       0  SUPPVIRTUAL       0  36.13409 -86.395110
# 381479  TN-00950  ...       0  SUPPVIRTUAL       0  36.13409 -86.395110
# 381480  TN-00950  ...       0  SUPPVIRTUAL       0  36.13409 -86.395110
#
#                   locale                    geometry  pct_met_exceeded_w  \
# 0         11-City: Large  POINT (-89.92364 35.21410)              35.952
# 1         11-City: Large  POINT (-89.92364 35.21410)              34.086
# 2         11-City: Large  POINT (-89.92364 35.21410)              35.880
# 3         11-City: Large  POINT (-89.92364 35.21410)              21.090
# 4         11-City: Large  POINT (-89.92364 35.21410)               2.002
# ...                  ...                         ...                 ...
# 381475  41-Rural: Fringe  POINT (-86.39511 36.13409)             139.968
# 381476  41-Rural: Fringe  POINT (-86.39511 36.13409)             142.992
# 381477  41-Rural: Fringe  POINT (-86.39511 36.13409)             149.075
# 381479  41-Rural: Fringe  POINT (-86.39511 36.13409)              26.058
# 381480  41-Rural: Fringe  POINT (-86.39511 36.13409)             131.880
#
#        stu_tchr_ratio_w fte_teachers_w
# 0               6654.33        8827.50
# 1               6198.27        8222.50
# 2               6467.76        8580.00
# 3               4602.06        6105.00
# 4                228.03         302.50
# ...                 ...            ...
# 381475          5514.48       29403.00
# 381476          5633.62       30038.25
# 381477          5701.70       30401.25
# 381479          2195.58       11706.75
# 381480          4765.60       25410.00
#
# [335452 rows x 27 columns]

# %%
unweighted = unweighted.loc[(unweighted['student_group'] == "All Students") | (unweighted['student_group'] == "Super Subgroup")]

# %%
unweighted.columns
# Out:
# Index(['year', 'system_name', 'school_name', 'test', 'subject', 'subject_area',
#        'student_group', 'valid_tests', 'pct_met_exceeded', 'system', 'school',
#        'school_lvl', 'tot_enrolled', 'fte_teachers', 'stu_tchr_ratio',
#        'school_type', 'magnet', 'charter', 'virtual', 'title_1', 'lat', 'long',
#        'locale', 'geometry', 'pct_met_exceeded_w', 'stu_tchr_ratio_w',
#        'fte_teachers_w'],
#       dtype='object')

# %% [markdown]
# The category for students not in the super subgroup does not exist.  Therefore, We'll need some algebra to construct it.  I will perform the calculations with a pivot table.

# %%
group_cols = ['year', 'system_name', 'school_name', 'test', 'subject', 'subject_area','system', 'school',
       'school_lvl', 'tot_enrolled', 'fte_teachers', 'stu_tchr_ratio',
       'school_type', 'magnet', 'charter', 'virtual', 'title_1', 'lat', 'long',
       'locale']

# %%
pivot_first = unweighted.pivot_table(columns = 'student_group',
                       values = 'valid_tests',
                      index = group_cols)

# %% [markdown]
# The "remaining" calculated variable represents the "non-ssg" group

# %%
pivot_first = unweighted.pivot_table(columns = 'student_group',
                       values = ('valid_tests', 'pct_met_exceeded'),
                      index = group_cols)
pivot_first[('valid_tests', 'remaining')] = pivot_first[('valid_tests','All Students')] - pivot_first[('valid_tests', 'Super Subgroup')]

# %%
pivot_first[('pct_met_exceeded', 'remaining')] = (pivot_first[('valid_tests','All Students')]*pivot_first[('pct_met_exceeded','All Students')] - pivot_first[('valid_tests','Super Subgroup')]*pivot_first[('pct_met_exceeded','Super Subgroup')])/pivot_first[('valid_tests','remaining')]

# %%
pivot_first
# Out:
#                                                                                                                                                                                                                                                                                 pct_met_exceeded  \
# student_group                                                                                                                                                                                                                                                                       All Students
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large             0.112
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large             0.096
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large             0.211
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large             0.109
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large             0.149
# ...                                                                                                                                                                                                                                                                                          ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe            0.263
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe            0.452
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe            0.541
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe            0.613
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe            0.639
#
#                                                                                                                                                                                                                                                                                                 \
# student_group                                                                                                                                                                                                                                                                   Super Subgroup
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           0.113
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           0.094
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           0.211
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large           0.107
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large           0.139
# ...                                                                                                                                                                                                                                                                                        ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe          0.222
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe          0.393
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe          0.500
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe          0.500
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe          0.556
#
#                                                                                                                                                                                                                                                                                  valid_tests  \
# student_group                                                                                                                                                                                                                                                                   All Students
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large         321.0
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large         322.0
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large         166.0
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large         238.0
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large          74.0
# ...                                                                                                                                                                                                                                                                                      ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         38.0
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         62.0
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         61.0
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         62.0
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         61.0
#
#                                                                                                                                                                                                                                                                                                 \
# student_group                                                                                                                                                                                                                                                                   Super Subgroup
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           318.0
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           319.0
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large           166.0
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large           233.0
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large            72.0
# ...                                                                                                                                                                                                                                                                                        ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe           18.0
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe           28.0
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe           28.0
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe           28.0
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe           27.0
#
#                                                                                                                                                                                                                                                                                            \
# student_group                                                                                                                                                                                                                                                                   remaining
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large        3.0
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large        3.0
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large        0.0
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large        5.0
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large        2.0
# ...                                                                                                                                                                                                                                                                                   ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe      20.0
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe      34.0
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe      33.0
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe      34.0
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe      34.0
#
#                                                                                                                                                                                                                                                                                 pct_met_exceeded
# student_group                                                                                                                                                                                                                                                                          remaining
# year system_name                 school_name                          test    subject        subject_area   system   school        school_lvl tot_enrolled fte_teachers stu_tchr_ratio school_type      magnet charter virtual     title_1 lat       long       locale
# 2018 Achievement School District Aspire Coleman                       TNReady ELA            ELA            TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large          0.006000
#                                                                               Math           Math           TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large          0.308667
#                                                                               Science        Science        TN-00985 TN-00985-8050 Elementary 570          27.50        20.73          1-Regular school 0      1       NOTVIRTUAL  1       35.214100 -89.923641 11-City: Large               NaN
#                                  Aspire Hanley Elementary             TNReady Math           Math           TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large          0.202200
#                                                                               Science        Science        TN-00985 TN-00985-8025 Elementary 513          19.50        26.31          1-Regular school 0      1       NOTVIRTUAL  1       35.113582 -89.976593 11-City: Large          0.509000
# ...                                                                                                                                                                                                                                                                                          ...
# 2022 Wilson County               Barry Tatum Virtual Learning Academy EOC     Geometry       Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         0.299900
#                                                                       TNReady ELA            ELA            TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         0.500588
#                                                                               Math           Math           TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         0.575788
#                                                                               Science        Science        TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         0.706059
#                                                                               Social Studies Social Studies TN-00950 TN-00950-0087 Other      222          16.93        13.11          1-Regular school 0      0       FACEVIRTUAL 0       36.167459 -86.305948 31-Town: Fringe         0.704912
#
# [27541 rows x 6 columns]

# %%
algebra = pivot_first['pct_met_exceeded'].melt(ignore_index = False).rename(columns = {'value':'pct_met_exceeded'}).reset_index()

# %%
# na = all students (Valid Tests)
# pa = pct_met(all students)
# ns = supersubgroup(Valdi Tests)
# ps = pct_met (supersubgroup)
# nr = remainder

# pr ?

# %% [markdown]
# > 🗂️ lvpp → last valid pre-pandemic assessment to 2021

# %%
group_cols = ['student_group', 'system_name', 'school_name', 'test', 'subject', 'subject_area','system', 'school',
       'school_lvl','school_type', 'magnet', 'charter', 'title_1','locale']

# %%
pivot_second = algebra.pivot_table(columns = 'year',
                       values = 'pct_met_exceeded',
                      index = group_cols)

# %% [markdown]
# Calculate lvpp epoch

# %%
# Last Valid Pre-Pandemic met_exceded measurement (lvpp)
pivot_second['lvpp']= pivot_second[2021] - pivot_second[2019]

# %%
lvpp = pivot_second.reset_index()

# %%
lvpp
# Out:
# year  student_group                  system_name                 school_name  \
# 0      All Students  Achievement School District              Aspire Coleman
# 1      All Students  Achievement School District              Aspire Coleman
# 2      All Students  Achievement School District              Aspire Coleman
# 3      All Students  Achievement School District    Aspire Hanley Elementary
# 4      All Students  Achievement School District    Aspire Hanley Elementary
# ...             ...                          ...                         ...
# 32633     remaining                Wilson County  Wilson Central High School
# 32634     remaining                Wilson County  Wilson Central High School
# 32635     remaining                Wilson County  Wilson Central High School
# 32636     remaining                Wilson County  Wilson Central High School
# 32637     remaining                Wilson County  Wilson Central High School
#
# year      test      subject    subject_area    system         school  \
# 0      TNReady          ELA             ELA  TN-00985  TN-00985-8050
# 1      TNReady         Math            Math  TN-00985  TN-00985-8050
# 2      TNReady      Science         Science  TN-00985  TN-00985-8050
# 3      TNReady          ELA             ELA  TN-00985  TN-00985-8025
# 4      TNReady         Math            Math  TN-00985  TN-00985-8025
# ...        ...          ...             ...       ...            ...
# 32633      EOC    English I             ELA  TN-00950  TN-00950-0073
# 32634      EOC   English II             ELA  TN-00950  TN-00950-0073
# 32635      EOC  English III             ELA  TN-00950  TN-00950-0073
# 32636      EOC     Geometry            Math  TN-00950  TN-00950-0073
# 32637      EOC   US History  Social Studies  TN-00950  TN-00950-0073
#
# year   school_lvl       school_type  magnet  charter title_1  \
# 0      Elementary  1-Regular school       0        1       1
# 1      Elementary  1-Regular school       0        1       1
# 2      Elementary  1-Regular school       0        1       1
# 3      Elementary  1-Regular school       0        1       1
# 4      Elementary  1-Regular school       0        1       1
# ...           ...               ...     ...      ...     ...
# 32633        High  1-Regular school       0        0       0
# 32634        High  1-Regular school       0        0       0
# 32635        High  1-Regular school       0        0       0
# 32636        High  1-Regular school       0        0       0
# 32637        High  1-Regular school       0        0       0
#
# year             locale      2018      2019      2021      2022      lvpp
# 0        11-City: Large  0.112000  0.061000       NaN       NaN       NaN
# 1        11-City: Large  0.096000  0.114000       NaN       NaN       NaN
# 2        11-City: Large  0.211000       NaN       NaN       NaN       NaN
# 3        11-City: Large       NaN  0.057000       NaN       NaN       NaN
# 4        11-City: Large  0.109000  0.147000       NaN       NaN       NaN
# ...                 ...       ...       ...       ...       ...       ...
# 32633  41-Rural: Fringe  0.439000  0.473529  0.502820  0.579268  0.029291
# 32634  41-Rural: Fringe  0.533250  0.725217  0.611364  0.749716 -0.113854
# 32635  41-Rural: Fringe  0.412840       NaN       NaN       NaN       NaN
# 32636  41-Rural: Fringe  0.373010  0.429425  0.437654  0.529321  0.008228
# 32637  41-Rural: Fringe  0.477323  0.517228       NaN       NaN       NaN
#
# [32638 rows x 19 columns]

# %% [markdown]
# ## Although there does seem to be a fair bit of uncertainty in the model, OLS indicates statistically signifigant difference in impact concerning ELA in different school levles for the ssg vs non-ssg student groups.

# %%
# Elem ela vs. ela in other school levels
# Explanatory
model_data = lvpp.dropna(subset = ['student_group', 'lvpp', 'school_lvl']).loc[lvpp['subject_area'] == 'ELA']

model_data = model_data.loc[model_data['student_group'] != 'All Students']

formula = 'lvpp ~ C(student_group) * C(school_lvl)'

model = smf.ols(formula = formula, data = model_data).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   lvpp   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     4.174
# Date:                Tue, 13 Jun 2023   Prob (F-statistic):           2.27e-05
# Time:                        19:09:30   Log-Likelihood:                 1858.9
# No. Observations:                2800   AIC:                            -3698.
# Df Residuals:                    2790   BIC:                            -3638.
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   -0.0375      0.004     -8.620      0.000      -0.046      -0.029
# C(student_group)[T.remaining]                               -0.0056      0.006     -0.897      0.370      -0.018       0.007
# C(school_lvl)[T.High]                                        0.0048      0.008      0.615      0.539      -0.010       0.020
# C(school_lvl)[T.Middle]                                     -0.0266      0.010     -2.737      0.006      -0.046      -0.008
# C(school_lvl)[T.Other]                                      -0.0028      0.024     -0.114      0.909      -0.051       0.045
# C(school_lvl)[T.Secondary]                                   0.0488      0.063      0.780      0.435      -0.074       0.171
# C(student_group)[T.remaining]:C(school_lvl)[T.High]         -0.0223      0.011     -1.994      0.046      -0.044      -0.000
# C(student_group)[T.remaining]:C(school_lvl)[T.Middle]       -0.0143      0.014     -1.029      0.304      -0.041       0.013
# C(student_group)[T.remaining]:C(school_lvl)[T.Other]         0.0168      0.035      0.487      0.627      -0.051       0.085
# C(student_group)[T.remaining]:C(school_lvl)[T.Secondary]    -0.0475      0.088     -0.537      0.591      -0.221       0.126
# ==============================================================================
# Omnibus:                      848.331   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57743.085
# Skew:                           0.540   Prob(JB):                         0.00
# Kurtosis:                      25.221   Cond. No.                         51.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## It appears as if there was a signifigant impact for elementary student ELA scores in charter schools vs non charter schools.

# %%
# Explanatory
model_data = lvpp.dropna(subset = ['student_group', 'lvpp', 'school_lvl']).loc[lvpp['subject_area'] == 'ELA']

model_data = model_data.loc[model_data['student_group'] == 'All Students']

formula = 'lvpp ~ C(charter)'

model = smf.ols(formula = formula, data = model_data).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   lvpp   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     10.47
# Date:                Tue, 13 Jun 2023   Prob (F-statistic):            0.00124
# Time:                        19:09:30   Log-Likelihood:                 1874.7
# No. Observations:                1494   AIC:                            -3745.
# Df Residuals:                    1492   BIC:                            -3735.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -0.0445      0.002    -24.297      0.000      -0.048      -0.041
# C(charter)[T.1]    -0.0272      0.008     -3.236      0.001      -0.044      -0.011
# ==============================================================================
# Omnibus:                       84.695   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              242.957
# Skew:                           0.255   Prob(JB):                     1.75e-53
# Kurtosis:                       4.909   Cond. No.                         4.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
